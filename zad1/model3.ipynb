# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from taskdataset import TaskDataset
import torchvision
import cv2

path_to_data = "datasets/" # TODO Set path to datasets files
path_to_models = "models/"

# import torch
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
# import torch.onnx
import onnx
import onnxscript
from torchsummary import summary

# %%
import pickle
import pandas as pd
dataset = pd.read_pickle(path_to_data + "data3.pck")

# %%
dataset2 = []

length = len(dataset)
# length = 100

for i in range(length):
    image = np.array(dataset['image'][i], dtype=np.uint8)


    if image.shape != (32, 32, 3):
        #convert to RGB
        # print(type(image[0]))
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        # print(image.shape)
    # image.astype(np.float32)
    #convert to tensor
    image = torch.from_numpy(image)

    image = image.to(torch.float32) / 255
    label = dataset['output'][i]
    # el = [image.reshape(3*32*32), label.astype(np.float32)]
    el = [image.reshape(3*32*32), label.astype(np.float32)]
    dataset2.append(el)
    # print(image)

# %%
dataset2[:80][0][0].shape
dataset2[:80][0][1].shape

val_split = 0.1
train_size = len(dataset2)
split = int(np.floor(val_split * train_size))
split
train_data = dataset2[split:]
val_data = dataset2[:split]

print(train_data[:80][0][0].shape)
train_data[:80][0][1].shape
# Out:
# torch.Size([3072])
# (512,)

# %%
t_loader = torch.utils.data.DataLoader(dataset = train_data,
                                     batch_size = 32,
                                     shuffle = True)

v_loader = torch.utils.data.DataLoader(dataset = val_data,
                                     batch_size = 32,
                                     shuffle = True)

dataloaders = {'train': t_loader, 'val': v_loader}

# %%
class AE(torch.nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = torch.nn.Sequential(

            torch.nn.Linear(3 * 32 * 32, 1536),
            torch.nn.ReLU(),
            torch.nn.Linear(1536, 1536),
            torch.nn.ReLU(),
            torch.nn.Linear(1536, 512),
            
        )
         
 
    def forward(self, x):
        # print(x)
        encoded = self.encoder(x)
        encoded.double()
        return encoded

# %%
# Model Initialization
model = AE()
 
# Validation using MSE Loss function
loss_function = torch.nn.MSELoss()
 
# Using an Adam Optimizer with lr = 0.1
optimizer = torch.optim.Adam(model.parameters(),
                             lr = 1e-1,
                             weight_decay = 1e-8)

# %%
epochs = 20
outputs = []
losses = []
all_losses = []
v_all_losses = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'

for epoch in range(epochs):
    
    print(f"\nEpoch {epoch+1} of {epochs}")
    print("-------------------------------")

    idx = -1

    mode = 'train'

    for loader in [t_loader, v_loader]:

      print(f"Load: {loader}")
      if mode == 'train':
        model.train()
        mode = 'val'
      else:
        model.eval()
        mode = 'train'

      for (image, labels) in loader:
        idx = idx + 1
        losses = []
        v_losses = []
        print(f"Epoch {epoch+1}, Bach {idx} of {len(loader)}")

        model.train()

        # Output of Autoencoder
        features = model(image)

        # Calculating the loss function
        loss = loss_function(features, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        

        # Storing the losses in a list for plotting
        if mode == 'train':
          losses.append(float(loss))
        elif type(float(loss)) is not np.nan:
          print(f"mode: {mode}, loss: {loss}")
          v_losses.append(float(loss))
        losses.append(float(loss))
      
      print(v_all_losses)
      all_losses.append(np.average(losses)) 
      v_all_losses.append(np.average(v_losses))


    torch.onnx.export(model,                                # model being run
                      torch.randn(3*32*32).to(device),    # model input (or a tuple for multiple inputs)
                      path_to_models + f"zad1_model_e{epoch}.onnx",           # where to save the model (can be a file or file-like object)
                      input_names = ['input'],              # the model's input names
                      output_names = ['output'])            # the model's output names
# Out:
# Epoch 1 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 1, Bach 0 of 29
# mode: val, loss: 1.4449810981750488
# Epoch 1, Bach 1 of 29
# mode: val, loss: 83347243008.0
# Epoch 1, Bach 2 of 29
# mode: val, loss: 3053208.5
# Epoch 1, Bach 3 of 29
# mode: val, loss: 24446.13671875
# Epoch 1, Bach 4 of 29
# mode: val, loss: 1274742.5
# Epoch 1, Bach 5 of 29
# mode: val, loss: 78988856.0
# Epoch 1, Bach 6 of 29
# mode: val, loss: 1764875.375
# Epoch 1, Bach 7 of 29
# mode: val, loss: 94938.3359375
# Epoch 1, Bach 8 of 29
# mode: val, loss: 651.182373046875
# Epoch 1, Bach 9 of 29
# mode: val, loss: 47716.0546875
# Epoch 1, Bach 10 of 29
# mode: val, loss: 156916.625
# Epoch 1, Bach 11 of 29
# mode: val, loss: 15181.6396484375
# Epoch 1, Bach 12 of 29
# mode: val, loss: 28801.654296875
# Epoch 1, Bach 13 of 29
# mode: val, loss: 3933.9150390625
# Epoch 1, Bach 14 of 29
# mode: val, loss: 72253.234375
# Epoch 1, Bach 15 of 29
# mode: val, loss: 19661.8359375
# Epoch 1, Bach 16 of 29
# mode: val, loss: 12443.849609375
# Epoch 1, Bach 17 of 29
# mode: val, loss: 84959.9453125
# Epoch 1, Bach 18 of 29
# mode: val, loss: 48296.44140625
# Epoch 1, Bach 19 of 29
# mode: val, loss: 14072.3603515625
# Epoch 1, Bach 20 of 29
# mode: val, loss: 6050.1435546875
# Epoch 1, Bach 21 of 29
# mode: val, loss: 57882.15234375
# Epoch 1, Bach 22 of 29
# mode: val, loss: 19866.921875
# Epoch 1, Bach 23 of 29
# mode: val, loss: 34607.05078125
# Epoch 1, Bach 24 of 29
# mode: val, loss: 44165.73046875
# Epoch 1, Bach 25 of 29
# mode: val, loss: 35420.9375
# Epoch 1, Bach 26 of 29
# mode: val, loss: 2800.82275390625
# Epoch 1, Bach 27 of 29
# mode: val, loss: 60977.8046875
# Epoch 1, Bach 28 of 29
# mode: val, loss: 750.171142578125
# []
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 1, Bach 29 of 4
# Epoch 1, Bach 30 of 4
# Epoch 1, Bach 31 of 4
# Epoch 1, Bach 32 of 4
# [750.171142578125]
# d:\programy\python3.11.6\Lib\site-packages\numpy\lib\function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# d:\programy\python3.11.6\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Epoch 2 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 2, Bach 0 of 29
# mode: val, loss: 16639.9609375
# Epoch 2, Bach 1 of 29
# mode: val, loss: 5121.10400390625
# Epoch 2, Bach 2 of 29
# mode: val, loss: 1306.9853515625
# Epoch 2, Bach 3 of 29
# mode: val, loss: 4589.72607421875
# Epoch 2, Bach 4 of 29
# mode: val, loss: 8344.1455078125
# Epoch 2, Bach 5 of 29
# mode: val, loss: 8129.13037109375
# Epoch 2, Bach 6 of 29
# mode: val, loss: 786.0443725585938
# Epoch 2, Bach 7 of 29
# mode: val, loss: 4662.63037109375
# Epoch 2, Bach 8 of 29
# mode: val, loss: 7011.20849609375
# Epoch 2, Bach 9 of 29
# mode: val, loss: 2733.44482421875
# Epoch 2, Bach 10 of 29
# mode: val, loss: 3080.755859375
# Epoch 2, Bach 11 of 29
# mode: val, loss: 2303.519287109375
# Epoch 2, Bach 12 of 29
# mode: val, loss: 167.7988739013672
# Epoch 2, Bach 13 of 29
# mode: val, loss: 2288.58935546875
# Epoch 2, Bach 14 of 29
# mode: val, loss: 952.8112182617188
# Epoch 2, Bach 15 of 29
# mode: val, loss: 219.47525024414062
# Epoch 2, Bach 16 of 29
# mode: val, loss: 2499.020751953125
# Epoch 2, Bach 17 of 29
# mode: val, loss: 564.2784423828125
# Epoch 2, Bach 18 of 29
# mode: val, loss: 155.72776794433594
# Epoch 2, Bach 19 of 29
# mode: val, loss: 820.9591064453125
# Epoch 2, Bach 20 of 29
# mode: val, loss: 688.6814575195312
# Epoch 2, Bach 21 of 29
# mode: val, loss: 3183.56982421875
# Epoch 2, Bach 22 of 29
# mode: val, loss: 612.0093994140625
# Epoch 2, Bach 23 of 29
# mode: val, loss: 2699.978515625
# Epoch 2, Bach 24 of 29
# mode: val, loss: 3047.638671875
# Epoch 2, Bach 25 of 29
# mode: val, loss: 472.2814025878906
# Epoch 2, Bach 26 of 29
# mode: val, loss: 333.40631103515625
# Epoch 2, Bach 27 of 29
# mode: val, loss: 4074.171142578125
# Epoch 2, Bach 28 of 29
# mode: val, loss: 703.1624145507812
# [750.171142578125, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 2, Bach 29 of 4
# Epoch 2, Bach 30 of 4
# Epoch 2, Bach 31 of 4
# Epoch 2, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812]
#
# Epoch 3 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 3, Bach 0 of 29
# mode: val, loss: 596.8441162109375
# Epoch 3, Bach 1 of 29
# mode: val, loss: 1995.761962890625
# Epoch 3, Bach 2 of 29
# mode: val, loss: 1014.0148315429688
# Epoch 3, Bach 3 of 29
# mode: val, loss: 105.85494995117188
# Epoch 3, Bach 4 of 29
# mode: val, loss: 1135.262939453125
# Epoch 3, Bach 5 of 29
# mode: val, loss: 1857.197265625
# Epoch 3, Bach 6 of 29
# mode: val, loss: 136.9300079345703
# Epoch 3, Bach 7 of 29
# mode: val, loss: 320.5143737792969
# Epoch 3, Bach 8 of 29
# mode: val, loss: 1225.557373046875
# Epoch 3, Bach 9 of 29
# mode: val, loss: 579.1046142578125
# Epoch 3, Bach 10 of 29
# mode: val, loss: 84.1652603149414
# Epoch 3, Bach 11 of 29
# mode: val, loss: 200.83773803710938
# Epoch 3, Bach 12 of 29
# mode: val, loss: 555.3084106445312
# Epoch 3, Bach 13 of 29
# mode: val, loss: 602.4935302734375
# Epoch 3, Bach 14 of 29
# mode: val, loss: 49.19667053222656
# Epoch 3, Bach 15 of 29
# mode: val, loss: 329.6247863769531
# Epoch 3, Bach 16 of 29
# mode: val, loss: 746.3782958984375
# Epoch 3, Bach 17 of 29
# mode: val, loss: 205.2261199951172
# Epoch 3, Bach 18 of 29
# mode: val, loss: 13.330687522888184
# Epoch 3, Bach 19 of 29
# mode: val, loss: 282.4689025878906
# Epoch 3, Bach 20 of 29
# mode: val, loss: 256.2235412597656
# Epoch 3, Bach 21 of 29
# mode: val, loss: 48.07603454589844
# Epoch 3, Bach 22 of 29
# mode: val, loss: 12.327295303344727
# Epoch 3, Bach 23 of 29
# mode: val, loss: 43.24765396118164
# Epoch 3, Bach 24 of 29
# mode: val, loss: 99.74320220947266
# Epoch 3, Bach 25 of 29
# mode: val, loss: 155.29466247558594
# Epoch 3, Bach 26 of 29
# mode: val, loss: 80.83413696289062
# Epoch 3, Bach 27 of 29
# mode: val, loss: 71.7498550415039
# Epoch 3, Bach 28 of 29
# mode: val, loss: 5.400332927703857
# [750.171142578125, nan, 703.1624145507812, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 3, Bach 29 of 4
# Epoch 3, Bach 30 of 4
# Epoch 3, Bach 31 of 4
# Epoch 3, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857]
#
# Epoch 4 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 4, Bach 0 of 29
# mode: val, loss: 170.0984649658203
# Epoch 4, Bach 1 of 29
# mode: val, loss: 13.77902603149414
# Epoch 4, Bach 2 of 29
# mode: val, loss: 50.160728454589844
# Epoch 4, Bach 3 of 29
# mode: val, loss: 72.63066864013672
# Epoch 4, Bach 4 of 29
# mode: val, loss: 25.140586853027344
# Epoch 4, Bach 5 of 29
# mode: val, loss: 7.732039928436279
# Epoch 4, Bach 6 of 29
# mode: val, loss: 33.20013427734375
# Epoch 4, Bach 7 of 29
# mode: val, loss: 24.93042755126953
# Epoch 4, Bach 8 of 29
# mode: val, loss: 17.446609497070312
# Epoch 4, Bach 9 of 29
# mode: val, loss: 4.311690330505371
# Epoch 4, Bach 10 of 29
# mode: val, loss: 15.270242691040039
# Epoch 4, Bach 11 of 29
# mode: val, loss: 22.763696670532227
# Epoch 4, Bach 12 of 29
# mode: val, loss: 12.076214790344238
# Epoch 4, Bach 13 of 29
# mode: val, loss: 16.648494720458984
# Epoch 4, Bach 14 of 29
# mode: val, loss: 12.332045555114746
# Epoch 4, Bach 15 of 29
# mode: val, loss: 16.825237274169922
# Epoch 4, Bach 16 of 29
# mode: val, loss: 16.282936096191406
# Epoch 4, Bach 17 of 29
# mode: val, loss: 3.999695301055908
# Epoch 4, Bach 18 of 29
# mode: val, loss: 39.126731872558594
# Epoch 4, Bach 19 of 29
# mode: val, loss: 6.698180675506592
# Epoch 4, Bach 20 of 29
# mode: val, loss: 6.053655624389648
# Epoch 4, Bach 21 of 29
# mode: val, loss: 2.6385364532470703
# Epoch 4, Bach 22 of 29
# mode: val, loss: 4.945366382598877
# Epoch 4, Bach 23 of 29
# mode: val, loss: 6.242798328399658
# Epoch 4, Bach 24 of 29
# mode: val, loss: 3.9450972080230713
# Epoch 4, Bach 25 of 29
# mode: val, loss: 3.8144924640655518
# Epoch 4, Bach 26 of 29
# mode: val, loss: 4.647514343261719
# Epoch 4, Bach 27 of 29
# mode: val, loss: 12.886270523071289
# Epoch 4, Bach 28 of 29
# mode: val, loss: 3.0144240856170654
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 4, Bach 29 of 4
# Epoch 4, Bach 30 of 4
# Epoch 4, Bach 31 of 4
# Epoch 4, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654]
#
# Epoch 5 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 5, Bach 0 of 29
# mode: val, loss: 2.5844807624816895
# Epoch 5, Bach 1 of 29
# mode: val, loss: 11.142301559448242
# Epoch 5, Bach 2 of 29
# mode: val, loss: 3.0787718296051025
# Epoch 5, Bach 3 of 29
# mode: val, loss: 3.371718406677246
# Epoch 5, Bach 4 of 29
# mode: val, loss: 4.2206220626831055
# Epoch 5, Bach 5 of 29
# mode: val, loss: 2.9007465839385986
# Epoch 5, Bach 6 of 29
# mode: val, loss: 2.2471563816070557
# Epoch 5, Bach 7 of 29
# mode: val, loss: 6.518021583557129
# Epoch 5, Bach 8 of 29
# mode: val, loss: 3.748350143432617
# Epoch 5, Bach 9 of 29
# mode: val, loss: 2.091257095336914
# Epoch 5, Bach 10 of 29
# mode: val, loss: 3.877155303955078
# Epoch 5, Bach 11 of 29
# mode: val, loss: 3.0212268829345703
# Epoch 5, Bach 12 of 29
# mode: val, loss: 2.6951003074645996
# Epoch 5, Bach 13 of 29
# mode: val, loss: 4.449362754821777
# Epoch 5, Bach 14 of 29
# mode: val, loss: 2.1324949264526367
# Epoch 5, Bach 15 of 29
# mode: val, loss: 2.75677490234375
# Epoch 5, Bach 16 of 29
# mode: val, loss: 2.6602632999420166
# Epoch 5, Bach 17 of 29
# mode: val, loss: 2.274150848388672
# Epoch 5, Bach 18 of 29
# mode: val, loss: 13.349630355834961
# Epoch 5, Bach 19 of 29
# mode: val, loss: 2.3510360717773438
# Epoch 5, Bach 20 of 29
# mode: val, loss: 2.053269147872925
# Epoch 5, Bach 21 of 29
# mode: val, loss: 2.231031656265259
# Epoch 5, Bach 22 of 29
# mode: val, loss: 2.5110630989074707
# Epoch 5, Bach 23 of 29
# mode: val, loss: 2.219937801361084
# Epoch 5, Bach 24 of 29
# mode: val, loss: 3.0701072216033936
# Epoch 5, Bach 25 of 29
# mode: val, loss: 2.133890390396118
# Epoch 5, Bach 26 of 29
# mode: val, loss: 5.838756561279297
# Epoch 5, Bach 27 of 29
# mode: val, loss: 2.3114616870880127
# Epoch 5, Bach 28 of 29
# mode: val, loss: 1.8098955154418945
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 5, Bach 29 of 4
# Epoch 5, Bach 30 of 4
# Epoch 5, Bach 31 of 4
# Epoch 5, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945]
#
# Epoch 6 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 6, Bach 0 of 29
# mode: val, loss: 3.5286614894866943
# Epoch 6, Bach 1 of 29
# mode: val, loss: 3.0882301330566406
# Epoch 6, Bach 2 of 29
# mode: val, loss: 2.0198259353637695
# Epoch 6, Bach 3 of 29
# mode: val, loss: 2.6524460315704346
# Epoch 6, Bach 4 of 29
# mode: val, loss: 2.1867482662200928
# Epoch 6, Bach 5 of 29
# mode: val, loss: 2.363245964050293
# Epoch 6, Bach 6 of 29
# mode: val, loss: 1.643852710723877
# Epoch 6, Bach 7 of 29
# mode: val, loss: 2.6920113563537598
# Epoch 6, Bach 8 of 29
# mode: val, loss: 4.682128429412842
# Epoch 6, Bach 9 of 29
# mode: val, loss: 2.185196876525879
# Epoch 6, Bach 10 of 29
# mode: val, loss: 2.1281204223632812
# Epoch 6, Bach 11 of 29
# mode: val, loss: 1.856134295463562
# Epoch 6, Bach 12 of 29
# mode: val, loss: 1.9871909618377686
# Epoch 6, Bach 13 of 29
# mode: val, loss: 4.069871425628662
# Epoch 6, Bach 14 of 29
# mode: val, loss: 2.176084041595459
# Epoch 6, Bach 15 of 29
# mode: val, loss: 2.139655590057373
# Epoch 6, Bach 16 of 29
# mode: val, loss: 10.699893951416016
# Epoch 6, Bach 17 of 29
# mode: val, loss: 2.573829174041748
# Epoch 6, Bach 18 of 29
# mode: val, loss: 3.5763003826141357
# Epoch 6, Bach 19 of 29
# mode: val, loss: 2.555704116821289
# Epoch 6, Bach 20 of 29
# mode: val, loss: 1.3379703760147095
# Epoch 6, Bach 21 of 29
# mode: val, loss: 2.09317684173584
# Epoch 6, Bach 22 of 29
# mode: val, loss: 2.2530627250671387
# Epoch 6, Bach 23 of 29
# mode: val, loss: 2.180175304412842
# Epoch 6, Bach 24 of 29
# mode: val, loss: 2.836167097091675
# Epoch 6, Bach 25 of 29
# mode: val, loss: 2.8784945011138916
# Epoch 6, Bach 26 of 29
# mode: val, loss: 2.663689374923706
# Epoch 6, Bach 27 of 29
# mode: val, loss: 1.7337570190429688
# Epoch 6, Bach 28 of 29
# mode: val, loss: 1.6529276371002197
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 6, Bach 29 of 4
# Epoch 6, Bach 30 of 4
# Epoch 6, Bach 31 of 4
# Epoch 6, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197]
#
# Epoch 7 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 7, Bach 0 of 29
# mode: val, loss: 2.6328089237213135
# Epoch 7, Bach 1 of 29
# mode: val, loss: 2.3902993202209473
# Epoch 7, Bach 2 of 29
# mode: val, loss: 8.949516296386719
# Epoch 7, Bach 3 of 29
# mode: val, loss: 1.7082546949386597
# Epoch 7, Bach 4 of 29
# mode: val, loss: 2.120358943939209
# Epoch 7, Bach 5 of 29
# mode: val, loss: 2.1356775760650635
# Epoch 7, Bach 6 of 29
# mode: val, loss: 2.166534662246704
# Epoch 7, Bach 7 of 29
# mode: val, loss: 2.2220187187194824
# Epoch 7, Bach 8 of 29
# mode: val, loss: 2.299938440322876
# Epoch 7, Bach 9 of 29
# mode: val, loss: 2.2408313751220703
# Epoch 7, Bach 10 of 29
# mode: val, loss: 1.7102419137954712
# Epoch 7, Bach 11 of 29
# mode: val, loss: 1.9371044635772705
# Epoch 7, Bach 12 of 29
# mode: val, loss: 1.5373104810714722
# Epoch 7, Bach 13 of 29
# mode: val, loss: 3.981653928756714
# Epoch 7, Bach 14 of 29
# mode: val, loss: 2.8924994468688965
# Epoch 7, Bach 15 of 29
# mode: val, loss: 2.0339934825897217
# Epoch 7, Bach 16 of 29
# mode: val, loss: 1.6566070318222046
# Epoch 7, Bach 17 of 29
# mode: val, loss: 1.691306471824646
# Epoch 7, Bach 18 of 29
# mode: val, loss: 2.1838536262512207
# Epoch 7, Bach 19 of 29
# mode: val, loss: 2.087744951248169
# Epoch 7, Bach 20 of 29
# mode: val, loss: 1.790022373199463
# Epoch 7, Bach 21 of 29
# mode: val, loss: 2.585326910018921
# Epoch 7, Bach 22 of 29
# mode: val, loss: 4.362809181213379
# Epoch 7, Bach 23 of 29
# mode: val, loss: 1.8499780893325806
# Epoch 7, Bach 24 of 29
# mode: val, loss: 1.5681265592575073
# Epoch 7, Bach 25 of 29
# mode: val, loss: 2.1194705963134766
# Epoch 7, Bach 26 of 29
# mode: val, loss: 1.6573036909103394
# Epoch 7, Bach 27 of 29
# mode: val, loss: 1.8299500942230225
# Epoch 7, Bach 28 of 29
# mode: val, loss: 1.65459406375885
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 7, Bach 29 of 4
# Epoch 7, Bach 30 of 4
# Epoch 7, Bach 31 of 4
# Epoch 7, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885]
#
# Epoch 8 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 8, Bach 0 of 29
# mode: val, loss: 1.870316743850708
# Epoch 8, Bach 1 of 29
# mode: val, loss: 2.341219425201416
# Epoch 8, Bach 2 of 29
# mode: val, loss: 1.5745466947555542
# Epoch 8, Bach 3 of 29
# mode: val, loss: 2.2553176879882812
# Epoch 8, Bach 4 of 29
# mode: val, loss: 1.6390681266784668
# Epoch 8, Bach 5 of 29
# mode: val, loss: 8.975611686706543
# Epoch 8, Bach 6 of 29
# mode: val, loss: 1.8356821537017822
# Epoch 8, Bach 7 of 29
# mode: val, loss: 4.7162580490112305
# Epoch 8, Bach 8 of 29
# mode: val, loss: 1.5812281370162964
# Epoch 8, Bach 9 of 29
# mode: val, loss: 1.6818958520889282
# Epoch 8, Bach 10 of 29
# mode: val, loss: 2.551893472671509
# Epoch 8, Bach 11 of 29
# mode: val, loss: 3.2873260974884033
# Epoch 8, Bach 12 of 29
# mode: val, loss: 3.7314298152923584
# Epoch 8, Bach 13 of 29
# mode: val, loss: 6.747071743011475
# Epoch 8, Bach 14 of 29
# mode: val, loss: 2.1828885078430176
# Epoch 8, Bach 15 of 29
# mode: val, loss: 4.202340602874756
# Epoch 8, Bach 16 of 29
# mode: val, loss: 2.4347071647644043
# Epoch 8, Bach 17 of 29
# mode: val, loss: 1.665515422821045
# Epoch 8, Bach 18 of 29
# mode: val, loss: 3.1324453353881836
# Epoch 8, Bach 19 of 29
# mode: val, loss: 3.0872573852539062
# Epoch 8, Bach 20 of 29
# mode: val, loss: 1.7930359840393066
# Epoch 8, Bach 21 of 29
# mode: val, loss: 2.7304112911224365
# Epoch 8, Bach 22 of 29
# mode: val, loss: 2.2440571784973145
# Epoch 8, Bach 23 of 29
# mode: val, loss: 1.5096333026885986
# Epoch 8, Bach 24 of 29
# mode: val, loss: 2.289043426513672
# Epoch 8, Bach 25 of 29
# mode: val, loss: 2.248391628265381
# Epoch 8, Bach 26 of 29
# mode: val, loss: 1.3718020915985107
# Epoch 8, Bach 27 of 29
# mode: val, loss: 1.4627559185028076
# Epoch 8, Bach 28 of 29
# mode: val, loss: 3.263709306716919
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 8, Bach 29 of 4
# Epoch 8, Bach 30 of 4
# Epoch 8, Bach 31 of 4
# Epoch 8, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919]
#
# Epoch 9 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 9, Bach 0 of 29
# mode: val, loss: 9.161992073059082
# Epoch 9, Bach 1 of 29
# mode: val, loss: 2.2763781547546387
# Epoch 9, Bach 2 of 29
# mode: val, loss: 1.720533847808838
# Epoch 9, Bach 3 of 29
# mode: val, loss: 2.4141345024108887
# Epoch 9, Bach 4 of 29
# mode: val, loss: 1.778476357460022
# Epoch 9, Bach 5 of 29
# mode: val, loss: 1.6238906383514404
# Epoch 9, Bach 6 of 29
# mode: val, loss: 2.4032392501831055
# Epoch 9, Bach 7 of 29
# mode: val, loss: 1.163772702217102
# Epoch 9, Bach 8 of 29
# mode: val, loss: 2.3727781772613525
# Epoch 9, Bach 9 of 29
# mode: val, loss: 2.0207669734954834
# Epoch 9, Bach 10 of 29
# mode: val, loss: 1.5836327075958252
# Epoch 9, Bach 11 of 29
# mode: val, loss: 1.7596522569656372
# Epoch 9, Bach 12 of 29
# mode: val, loss: 1.5741970539093018
# Epoch 9, Bach 13 of 29
# mode: val, loss: 1.8278695344924927
# Epoch 9, Bach 14 of 29
# mode: val, loss: 1.4665343761444092
# Epoch 9, Bach 15 of 29
# mode: val, loss: 2.2567365169525146
# Epoch 9, Bach 16 of 29
# mode: val, loss: 2.4767022132873535
# Epoch 9, Bach 17 of 29
# mode: val, loss: 1.97165048122406
# Epoch 9, Bach 18 of 29
# mode: val, loss: 1.5305323600769043
# Epoch 9, Bach 19 of 29
# mode: val, loss: 1.658464789390564
# Epoch 9, Bach 20 of 29
# mode: val, loss: 2.302823543548584
# Epoch 9, Bach 21 of 29
# mode: val, loss: 1.6934248208999634
# Epoch 9, Bach 22 of 29
# mode: val, loss: 2.074788808822632
# Epoch 9, Bach 23 of 29
# mode: val, loss: 1.4590307474136353
# Epoch 9, Bach 24 of 29
# mode: val, loss: 1.4876877069473267
# Epoch 9, Bach 25 of 29
# mode: val, loss: 1.5059566497802734
# Epoch 9, Bach 26 of 29
# mode: val, loss: 2.901562213897705
# Epoch 9, Bach 27 of 29
# mode: val, loss: 1.3324365615844727
# Epoch 9, Bach 28 of 29
# mode: val, loss: 2.0935652256011963
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 9, Bach 29 of 4
# Epoch 9, Bach 30 of 4
# Epoch 9, Bach 31 of 4
# Epoch 9, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963]
#
# Epoch 10 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 10, Bach 0 of 29
# mode: val, loss: 1.9452931880950928
# Epoch 10, Bach 1 of 29
# mode: val, loss: 1.235980749130249
# Epoch 10, Bach 2 of 29
# mode: val, loss: 1.7489066123962402
# Epoch 10, Bach 3 of 29
# mode: val, loss: 2.7694549560546875
# Epoch 10, Bach 4 of 29
# mode: val, loss: 1.6888041496276855
# Epoch 10, Bach 5 of 29
# mode: val, loss: 1.275084376335144
# Epoch 10, Bach 6 of 29
# mode: val, loss: 1.5407538414001465
# Epoch 10, Bach 7 of 29
# mode: val, loss: 1.528661847114563
# Epoch 10, Bach 8 of 29
# mode: val, loss: 1.5919880867004395
# Epoch 10, Bach 9 of 29
# mode: val, loss: 1.368630051612854
# Epoch 10, Bach 10 of 29
# mode: val, loss: 6.049023151397705
# Epoch 10, Bach 11 of 29
# mode: val, loss: 1.3736035823822021
# Epoch 10, Bach 12 of 29
# mode: val, loss: 1.2653378248214722
# Epoch 10, Bach 13 of 29
# mode: val, loss: 1.6121000051498413
# Epoch 10, Bach 14 of 29
# mode: val, loss: 1.4828357696533203
# Epoch 10, Bach 15 of 29
# mode: val, loss: 1.3402655124664307
# Epoch 10, Bach 16 of 29
# mode: val, loss: 1.522220492362976
# Epoch 10, Bach 17 of 29
# mode: val, loss: 1.3495237827301025
# Epoch 10, Bach 18 of 29
# mode: val, loss: 1.26875638961792
# Epoch 10, Bach 19 of 29
# mode: val, loss: 1.4889565706253052
# Epoch 10, Bach 20 of 29
# mode: val, loss: 1.1683907508850098
# Epoch 10, Bach 21 of 29
# mode: val, loss: 1.2260193824768066
# Epoch 10, Bach 22 of 29
# mode: val, loss: 1.335470199584961
# Epoch 10, Bach 23 of 29
# mode: val, loss: 1.2920217514038086
# Epoch 10, Bach 24 of 29
# mode: val, loss: 2.1327850818634033
# Epoch 10, Bach 25 of 29
# mode: val, loss: 2.422947645187378
# Epoch 10, Bach 26 of 29
# mode: val, loss: 1.326911211013794
# Epoch 10, Bach 27 of 29
# mode: val, loss: 1.47324800491333
# Epoch 10, Bach 28 of 29
# mode: val, loss: 1.2870519161224365
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 10, Bach 29 of 4
# Epoch 10, Bach 30 of 4
# Epoch 10, Bach 31 of 4
# Epoch 10, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365]
#
# Epoch 11 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 11, Bach 0 of 29
# mode: val, loss: 1.5761460065841675
# Epoch 11, Bach 1 of 29
# mode: val, loss: 1.461026668548584
# Epoch 11, Bach 2 of 29
# mode: val, loss: 2.4718732833862305
# Epoch 11, Bach 3 of 29
# mode: val, loss: 1.6008415222167969
# Epoch 11, Bach 4 of 29
# mode: val, loss: 2.180424690246582
# Epoch 11, Bach 5 of 29
# mode: val, loss: 1.5522184371948242
# Epoch 11, Bach 6 of 29
# mode: val, loss: 5.65057373046875
# Epoch 11, Bach 7 of 29
# mode: val, loss: 1.7189501523971558
# Epoch 11, Bach 8 of 29
# mode: val, loss: 1.2940847873687744
# Epoch 11, Bach 9 of 29
# mode: val, loss: 1.5059449672698975
# Epoch 11, Bach 10 of 29
# mode: val, loss: 1.5569220781326294
# Epoch 11, Bach 11 of 29
# mode: val, loss: 1.4405333995819092
# Epoch 11, Bach 12 of 29
# mode: val, loss: 2.0469071865081787
# Epoch 11, Bach 13 of 29
# mode: val, loss: 1.4042587280273438
# Epoch 11, Bach 14 of 29
# mode: val, loss: 2.3895950317382812
# Epoch 11, Bach 15 of 29
# mode: val, loss: 1.9021620750427246
# Epoch 11, Bach 16 of 29
# mode: val, loss: 1.587469458580017
# Epoch 11, Bach 17 of 29
# mode: val, loss: 2.3798835277557373
# Epoch 11, Bach 18 of 29
# mode: val, loss: 1.8217487335205078
# Epoch 11, Bach 19 of 29
# mode: val, loss: 2.62040114402771
# Epoch 11, Bach 20 of 29
# mode: val, loss: 2.260468006134033
# Epoch 11, Bach 21 of 29
# mode: val, loss: 1.3638014793395996
# Epoch 11, Bach 22 of 29
# mode: val, loss: 1.5098927021026611
# Epoch 11, Bach 23 of 29
# mode: val, loss: 1.3093717098236084
# Epoch 11, Bach 24 of 29
# mode: val, loss: 1.3124573230743408
# Epoch 11, Bach 25 of 29
# mode: val, loss: 1.9173426628112793
# Epoch 11, Bach 26 of 29
# mode: val, loss: 1.6147032976150513
# Epoch 11, Bach 27 of 29
# mode: val, loss: 1.7098220586776733
# Epoch 11, Bach 28 of 29
# mode: val, loss: 0.854505181312561
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 11, Bach 29 of 4
# Epoch 11, Bach 30 of 4
# Epoch 11, Bach 31 of 4
# Epoch 11, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561]
#
# Epoch 12 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 12, Bach 0 of 29
# mode: val, loss: 1.573330044746399
# Epoch 12, Bach 1 of 29
# mode: val, loss: 1.478240966796875
# Epoch 12, Bach 2 of 29
# mode: val, loss: 1.494128942489624
# Epoch 12, Bach 3 of 29
# mode: val, loss: 1.4713466167449951
# Epoch 12, Bach 4 of 29
# mode: val, loss: 1.8037258386611938
# Epoch 12, Bach 5 of 29
# mode: val, loss: 1.0506532192230225
# Epoch 12, Bach 6 of 29
# mode: val, loss: 1.6724947690963745
# Epoch 12, Bach 7 of 29
# mode: val, loss: 1.8343150615692139
# Epoch 12, Bach 8 of 29
# mode: val, loss: 2.1242761611938477
# Epoch 12, Bach 9 of 29
# mode: val, loss: 2.2885355949401855
# Epoch 12, Bach 10 of 29
# mode: val, loss: 6.721405982971191
# Epoch 12, Bach 11 of 29
# mode: val, loss: 1.4906353950500488
# Epoch 12, Bach 12 of 29
# mode: val, loss: 3.287670850753784
# Epoch 12, Bach 13 of 29
# mode: val, loss: 1.5046594142913818
# Epoch 12, Bach 14 of 29
# mode: val, loss: 3.7003605365753174
# Epoch 12, Bach 15 of 29
# mode: val, loss: 1.779625654220581
# Epoch 12, Bach 16 of 29
# mode: val, loss: 2.0944137573242188
# Epoch 12, Bach 17 of 29
# mode: val, loss: 3.0128860473632812
# Epoch 12, Bach 18 of 29
# mode: val, loss: 1.7777175903320312
# Epoch 12, Bach 19 of 29
# mode: val, loss: 2.441967010498047
# Epoch 12, Bach 20 of 29
# mode: val, loss: 1.4135472774505615
# Epoch 12, Bach 21 of 29
# mode: val, loss: 2.5688083171844482
# Epoch 12, Bach 22 of 29
# mode: val, loss: 1.6728826761245728
# Epoch 12, Bach 23 of 29
# mode: val, loss: 1.5522150993347168
# Epoch 12, Bach 24 of 29
# mode: val, loss: 1.6543242931365967
# Epoch 12, Bach 25 of 29
# mode: val, loss: 2.1341500282287598
# Epoch 12, Bach 26 of 29
# mode: val, loss: 1.5608259439468384
# Epoch 12, Bach 27 of 29
# mode: val, loss: 1.8295009136199951
# Epoch 12, Bach 28 of 29
# mode: val, loss: 0.9712470769882202
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 12, Bach 29 of 4
# Epoch 12, Bach 30 of 4
# Epoch 12, Bach 31 of 4
# Epoch 12, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202]
#
# Epoch 13 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 13, Bach 0 of 29
# mode: val, loss: 1.1001551151275635
# Epoch 13, Bach 1 of 29
# mode: val, loss: 1.2549278736114502
# Epoch 13, Bach 2 of 29
# mode: val, loss: 1.9806032180786133
# Epoch 13, Bach 3 of 29
# mode: val, loss: 1.5882452726364136
# Epoch 13, Bach 4 of 29
# mode: val, loss: 1.8804394006729126
# Epoch 13, Bach 5 of 29
# mode: val, loss: 2.394380807876587
# Epoch 13, Bach 6 of 29
# mode: val, loss: 2.12471866607666
# Epoch 13, Bach 7 of 29
# mode: val, loss: 5.870865821838379
# Epoch 13, Bach 8 of 29
# mode: val, loss: 1.8105764389038086
# Epoch 13, Bach 9 of 29
# mode: val, loss: 4.655892372131348
# Epoch 13, Bach 10 of 29
# mode: val, loss: 2.382730007171631
# Epoch 13, Bach 11 of 29
# mode: val, loss: 3.815969467163086
# Epoch 13, Bach 12 of 29
# mode: val, loss: 1.3920586109161377
# Epoch 13, Bach 13 of 29
# mode: val, loss: 2.2039430141448975
# Epoch 13, Bach 14 of 29
# mode: val, loss: 3.2393338680267334
# Epoch 13, Bach 15 of 29
# mode: val, loss: 1.6521917581558228
# Epoch 13, Bach 16 of 29
# mode: val, loss: 3.077136516571045
# Epoch 13, Bach 17 of 29
# mode: val, loss: 1.439396619796753
# Epoch 13, Bach 18 of 29
# mode: val, loss: 2.7387568950653076
# Epoch 13, Bach 19 of 29
# mode: val, loss: 1.8096143007278442
# Epoch 13, Bach 20 of 29
# mode: val, loss: 1.4913251399993896
# Epoch 13, Bach 21 of 29
# mode: val, loss: 2.196450710296631
# Epoch 13, Bach 22 of 29
# mode: val, loss: 1.343445062637329
# Epoch 13, Bach 23 of 29
# mode: val, loss: 1.5140420198440552
# Epoch 13, Bach 24 of 29
# mode: val, loss: 1.4513981342315674
# Epoch 13, Bach 25 of 29
# mode: val, loss: 1.444771647453308
# Epoch 13, Bach 26 of 29
# mode: val, loss: 1.6530735492706299
# Epoch 13, Bach 27 of 29
# mode: val, loss: 1.0685945749282837
# Epoch 13, Bach 28 of 29
# mode: val, loss: 1.1281683444976807
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 13, Bach 29 of 4
# Epoch 13, Bach 30 of 4
# Epoch 13, Bach 31 of 4
# Epoch 13, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807]
#
# Epoch 14 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 14, Bach 0 of 29
# mode: val, loss: 1.4368007183074951
# Epoch 14, Bach 1 of 29
# mode: val, loss: 1.2138879299163818
# Epoch 14, Bach 2 of 29
# mode: val, loss: 1.8398081064224243
# Epoch 14, Bach 3 of 29
# mode: val, loss: 1.733123779296875
# Epoch 14, Bach 4 of 29
# mode: val, loss: 1.8845769166946411
# Epoch 14, Bach 5 of 29
# mode: val, loss: 1.6276450157165527
# Epoch 14, Bach 6 of 29
# mode: val, loss: 1.3879573345184326
# Epoch 14, Bach 7 of 29
# mode: val, loss: 1.3094475269317627
# Epoch 14, Bach 8 of 29
# mode: val, loss: 1.4292970895767212
# Epoch 14, Bach 9 of 29
# mode: val, loss: 1.2428948879241943
# Epoch 14, Bach 10 of 29
# mode: val, loss: 1.315497636795044
# Epoch 14, Bach 11 of 29
# mode: val, loss: 2.5471243858337402
# Epoch 14, Bach 12 of 29
# mode: val, loss: 1.2438490390777588
# Epoch 14, Bach 13 of 29
# mode: val, loss: 2.087397813796997
# Epoch 14, Bach 14 of 29
# mode: val, loss: 1.5512975454330444
# Epoch 14, Bach 15 of 29
# mode: val, loss: 1.9960873126983643
# Epoch 14, Bach 16 of 29
# mode: val, loss: 1.1806817054748535
# Epoch 14, Bach 17 of 29
# mode: val, loss: 1.573030710220337
# Epoch 14, Bach 18 of 29
# mode: val, loss: 1.515463948249817
# Epoch 14, Bach 19 of 29
# mode: val, loss: 1.2942421436309814
# Epoch 14, Bach 20 of 29
# mode: val, loss: 1.6296480894088745
# Epoch 14, Bach 21 of 29
# mode: val, loss: 1.4287840127944946
# Epoch 14, Bach 22 of 29
# mode: val, loss: 1.5425724983215332
# Epoch 14, Bach 23 of 29
# mode: val, loss: 1.6122883558273315
# Epoch 14, Bach 24 of 29
# mode: val, loss: 1.2897706031799316
# Epoch 14, Bach 25 of 29
# mode: val, loss: 1.7456072568893433
# Epoch 14, Bach 26 of 29
# mode: val, loss: 4.249640941619873
# Epoch 14, Bach 27 of 29
# mode: val, loss: 2.4169962406158447
# Epoch 14, Bach 28 of 29
# mode: val, loss: 1.2799394130706787
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 14, Bach 29 of 4
# Epoch 14, Bach 30 of 4
# Epoch 14, Bach 31 of 4
# Epoch 14, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787]
#
# Epoch 15 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 15, Bach 0 of 29
# mode: val, loss: 2.154571056365967
# Epoch 15, Bach 1 of 29
# mode: val, loss: 1.2867804765701294
# Epoch 15, Bach 2 of 29
# mode: val, loss: 1.3486812114715576
# Epoch 15, Bach 3 of 29
# mode: val, loss: 1.4753100872039795
# Epoch 15, Bach 4 of 29
# mode: val, loss: 1.4616007804870605
# Epoch 15, Bach 5 of 29
# mode: val, loss: 1.151374101638794
# Epoch 15, Bach 6 of 29
# mode: val, loss: 1.2654155492782593
# Epoch 15, Bach 7 of 29
# mode: val, loss: 1.3966987133026123
# Epoch 15, Bach 8 of 29
# mode: val, loss: 1.226256012916565
# Epoch 15, Bach 9 of 29
# mode: val, loss: 1.1601755619049072
# Epoch 15, Bach 10 of 29
# mode: val, loss: 1.157103419303894
# Epoch 15, Bach 11 of 29
# mode: val, loss: 1.4703929424285889
# Epoch 15, Bach 12 of 29
# mode: val, loss: 1.3161565065383911
# Epoch 15, Bach 13 of 29
# mode: val, loss: 1.0745537281036377
# Epoch 15, Bach 14 of 29
# mode: val, loss: 1.6859667301177979
# Epoch 15, Bach 15 of 29
# mode: val, loss: 1.1079086065292358
# Epoch 15, Bach 16 of 29
# mode: val, loss: 1.1082735061645508
# Epoch 15, Bach 17 of 29
# mode: val, loss: 4.035093307495117
# Epoch 15, Bach 18 of 29
# mode: val, loss: 1.868053674697876
# Epoch 15, Bach 19 of 29
# mode: val, loss: 1.2309250831604004
# Epoch 15, Bach 20 of 29
# mode: val, loss: 1.363860845565796
# Epoch 15, Bach 21 of 29
# mode: val, loss: 1.7622390985488892
# Epoch 15, Bach 22 of 29
# mode: val, loss: 1.8152915239334106
# Epoch 15, Bach 23 of 29
# mode: val, loss: 2.0113301277160645
# Epoch 15, Bach 24 of 29
# mode: val, loss: 1.6868900060653687
# Epoch 15, Bach 25 of 29
# mode: val, loss: 1.8365764617919922
# Epoch 15, Bach 26 of 29
# mode: val, loss: 1.2395583391189575
# Epoch 15, Bach 27 of 29
# mode: val, loss: 1.3364155292510986
# Epoch 15, Bach 28 of 29
# mode: val, loss: 1.3658664226531982
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 15, Bach 29 of 4
# Epoch 15, Bach 30 of 4
# Epoch 15, Bach 31 of 4
# Epoch 15, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982]
#
# Epoch 16 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 16, Bach 0 of 29
# mode: val, loss: 1.6437013149261475
# Epoch 16, Bach 1 of 29
# mode: val, loss: 1.2176549434661865
# Epoch 16, Bach 2 of 29
# mode: val, loss: 1.5599138736724854
# Epoch 16, Bach 3 of 29
# mode: val, loss: 1.5250539779663086
# Epoch 16, Bach 4 of 29
# mode: val, loss: 1.70306396484375
# Epoch 16, Bach 5 of 29
# mode: val, loss: 3.293461799621582
# Epoch 16, Bach 6 of 29
# mode: val, loss: 1.8903809785842896
# Epoch 16, Bach 7 of 29
# mode: val, loss: 1.262906551361084
# Epoch 16, Bach 8 of 29
# mode: val, loss: 1.5432839393615723
# Epoch 16, Bach 9 of 29
# mode: val, loss: 1.4689245223999023
# Epoch 16, Bach 10 of 29
# mode: val, loss: 1.1558247804641724
# Epoch 16, Bach 11 of 29
# mode: val, loss: 1.0974969863891602
# Epoch 16, Bach 12 of 29
# mode: val, loss: 1.4733176231384277
# Epoch 16, Bach 13 of 29
# mode: val, loss: 1.2678208351135254
# Epoch 16, Bach 14 of 29
# mode: val, loss: 1.4950557947158813
# Epoch 16, Bach 15 of 29
# mode: val, loss: 1.077095627784729
# Epoch 16, Bach 16 of 29
# mode: val, loss: 1.4729013442993164
# Epoch 16, Bach 17 of 29
# mode: val, loss: 1.348219394683838
# Epoch 16, Bach 18 of 29
# mode: val, loss: 1.2124356031417847
# Epoch 16, Bach 19 of 29
# mode: val, loss: 1.5564180612564087
# Epoch 16, Bach 20 of 29
# mode: val, loss: 1.2540737390518188
# Epoch 16, Bach 21 of 29
# mode: val, loss: 1.1215959787368774
# Epoch 16, Bach 22 of 29
# mode: val, loss: 1.308881163597107
# Epoch 16, Bach 23 of 29
# mode: val, loss: 1.3078919649124146
# Epoch 16, Bach 24 of 29
# mode: val, loss: 1.1315076351165771
# Epoch 16, Bach 25 of 29
# mode: val, loss: 1.5432298183441162
# Epoch 16, Bach 26 of 29
# mode: val, loss: 1.3081300258636475
# Epoch 16, Bach 27 of 29
# mode: val, loss: 1.4110547304153442
# Epoch 16, Bach 28 of 29
# mode: val, loss: 1.3479626178741455
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 16, Bach 29 of 4
# Epoch 16, Bach 30 of 4
# Epoch 16, Bach 31 of 4
# Epoch 16, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455]
#
# Epoch 17 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 17, Bach 0 of 29
# mode: val, loss: 1.443117618560791
# Epoch 17, Bach 1 of 29
# mode: val, loss: 1.4116401672363281
# Epoch 17, Bach 2 of 29
# mode: val, loss: 1.2385129928588867
# Epoch 17, Bach 3 of 29
# mode: val, loss: 1.246803641319275
# Epoch 17, Bach 4 of 29
# mode: val, loss: 1.1709635257720947
# Epoch 17, Bach 5 of 29
# mode: val, loss: 1.1531022787094116
# Epoch 17, Bach 6 of 29
# mode: val, loss: 1.2042515277862549
# Epoch 17, Bach 7 of 29
# mode: val, loss: 1.3967112302780151
# Epoch 17, Bach 8 of 29
# mode: val, loss: 1.2774842977523804
# Epoch 17, Bach 9 of 29
# mode: val, loss: 1.1367988586425781
# Epoch 17, Bach 10 of 29
# mode: val, loss: 1.0856096744537354
# Epoch 17, Bach 11 of 29
# mode: val, loss: 1.2075303792953491
# Epoch 17, Bach 12 of 29
# mode: val, loss: 1.5020222663879395
# Epoch 17, Bach 13 of 29
# mode: val, loss: 1.1188887357711792
# Epoch 17, Bach 14 of 29
# mode: val, loss: 1.079829454421997
# Epoch 17, Bach 15 of 29
# mode: val, loss: 1.276131272315979
# Epoch 17, Bach 16 of 29
# mode: val, loss: 1.1689472198486328
# Epoch 17, Bach 17 of 29
# mode: val, loss: 1.1890900135040283
# Epoch 17, Bach 18 of 29
# mode: val, loss: 1.2602245807647705
# Epoch 17, Bach 19 of 29
# mode: val, loss: 1.5569682121276855
# Epoch 17, Bach 20 of 29
# mode: val, loss: 1.7090129852294922
# Epoch 17, Bach 21 of 29
# mode: val, loss: 1.3736536502838135
# Epoch 17, Bach 22 of 29
# mode: val, loss: 1.2856298685073853
# Epoch 17, Bach 23 of 29
# mode: val, loss: 1.7099440097808838
# Epoch 17, Bach 24 of 29
# mode: val, loss: 1.870093822479248
# Epoch 17, Bach 25 of 29
# mode: val, loss: 1.1224799156188965
# Epoch 17, Bach 26 of 29
# mode: val, loss: 4.609038352966309
# Epoch 17, Bach 27 of 29
# mode: val, loss: 1.0387235879898071
# Epoch 17, Bach 28 of 29
# mode: val, loss: 2.4581451416015625
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 17, Bach 29 of 4
# Epoch 17, Bach 30 of 4
# Epoch 17, Bach 31 of 4
# Epoch 17, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625]
#
# Epoch 18 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 18, Bach 0 of 29
# mode: val, loss: 6.576942443847656
# Epoch 18, Bach 1 of 29
# mode: val, loss: 3.2004079818725586
# Epoch 18, Bach 2 of 29
# mode: val, loss: 5.831051349639893
# Epoch 18, Bach 3 of 29
# mode: val, loss: 4.752572059631348
# Epoch 18, Bach 4 of 29
# mode: val, loss: 5.002237796783447
# Epoch 18, Bach 5 of 29
# mode: val, loss: 15.74661636352539
# Epoch 18, Bach 6 of 29
# mode: val, loss: 10.944870948791504
# Epoch 18, Bach 7 of 29
# mode: val, loss: 4.227428436279297
# Epoch 18, Bach 8 of 29
# mode: val, loss: 4.148103713989258
# Epoch 18, Bach 9 of 29
# mode: val, loss: 2.067413806915283
# Epoch 18, Bach 10 of 29
# mode: val, loss: 1.0742168426513672
# Epoch 18, Bach 11 of 29
# mode: val, loss: 2.5345773696899414
# Epoch 18, Bach 12 of 29
# mode: val, loss: 1.109182596206665
# Epoch 18, Bach 13 of 29
# mode: val, loss: 2.1188085079193115
# Epoch 18, Bach 14 of 29
# mode: val, loss: 1.112930178642273
# Epoch 18, Bach 15 of 29
# mode: val, loss: 1.6939599514007568
# Epoch 18, Bach 16 of 29
# mode: val, loss: 1.683997392654419
# Epoch 18, Bach 17 of 29
# mode: val, loss: 1.2416437864303589
# Epoch 18, Bach 18 of 29
# mode: val, loss: 1.6620744466781616
# Epoch 18, Bach 19 of 29
# mode: val, loss: 1.5189697742462158
# Epoch 18, Bach 20 of 29
# mode: val, loss: 1.0597585439682007
# Epoch 18, Bach 21 of 29
# mode: val, loss: 1.332473874092102
# Epoch 18, Bach 22 of 29
# mode: val, loss: 1.2150355577468872
# Epoch 18, Bach 23 of 29
# mode: val, loss: 1.3495638370513916
# Epoch 18, Bach 24 of 29
# mode: val, loss: 1.068913459777832
# Epoch 18, Bach 25 of 29
# mode: val, loss: 1.4261554479599
# Epoch 18, Bach 26 of 29
# mode: val, loss: 2.793914318084717
# Epoch 18, Bach 27 of 29
# mode: val, loss: 1.1905536651611328
# Epoch 18, Bach 28 of 29
# mode: val, loss: 1.6751019954681396
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 18, Bach 29 of 4
# Epoch 18, Bach 30 of 4
# Epoch 18, Bach 31 of 4
# Epoch 18, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan, 1.6751019954681396]
#
# Epoch 19 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 19, Bach 0 of 29
# mode: val, loss: 1.1243945360183716
# Epoch 19, Bach 1 of 29
# mode: val, loss: 1.2267991304397583
# Epoch 19, Bach 2 of 29
# mode: val, loss: 1.0081909894943237
# Epoch 19, Bach 3 of 29
# mode: val, loss: 1.3458057641983032
# Epoch 19, Bach 4 of 29
# mode: val, loss: 1.1295826435089111
# Epoch 19, Bach 5 of 29
# mode: val, loss: 1.3741886615753174
# Epoch 19, Bach 6 of 29
# mode: val, loss: 1.5271841287612915
# Epoch 19, Bach 7 of 29
# mode: val, loss: 1.2745544910430908
# Epoch 19, Bach 8 of 29
# mode: val, loss: 1.2158539295196533
# Epoch 19, Bach 9 of 29
# mode: val, loss: 1.2447649240493774
# Epoch 19, Bach 10 of 29
# mode: val, loss: 1.3389109373092651
# Epoch 19, Bach 11 of 29
# mode: val, loss: 1.4299168586730957
# Epoch 19, Bach 12 of 29
# mode: val, loss: 1.1524741649627686
# Epoch 19, Bach 13 of 29
# mode: val, loss: 1.1386806964874268
# Epoch 19, Bach 14 of 29
# mode: val, loss: 1.3341848850250244
# Epoch 19, Bach 15 of 29
# mode: val, loss: 1.3586857318878174
# Epoch 19, Bach 16 of 29
# mode: val, loss: 1.231967568397522
# Epoch 19, Bach 17 of 29
# mode: val, loss: 2.8876545429229736
# Epoch 19, Bach 18 of 29
# mode: val, loss: 1.4738049507141113
# Epoch 19, Bach 19 of 29
# mode: val, loss: 1.3587989807128906
# Epoch 19, Bach 20 of 29
# mode: val, loss: 1.4076097011566162
# Epoch 19, Bach 21 of 29
# mode: val, loss: 1.5140005350112915
# Epoch 19, Bach 22 of 29
# mode: val, loss: 1.2680857181549072
# Epoch 19, Bach 23 of 29
# mode: val, loss: 1.386873483657837
# Epoch 19, Bach 24 of 29
# mode: val, loss: 1.2645549774169922
# Epoch 19, Bach 25 of 29
# mode: val, loss: 1.2889645099639893
# Epoch 19, Bach 26 of 29
# mode: val, loss: 1.2162472009658813
# Epoch 19, Bach 27 of 29
# mode: val, loss: 1.609063744544983
# Epoch 19, Bach 28 of 29
# mode: val, loss: 0.9789684414863586
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan, 1.6751019954681396, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 19, Bach 29 of 4
# Epoch 19, Bach 30 of 4
# Epoch 19, Bach 31 of 4
# Epoch 19, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan, 1.6751019954681396, nan, 0.9789684414863586]
#
# Epoch 20 of 20
# -------------------------------
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B5F590>
# Epoch 20, Bach 0 of 29
# mode: val, loss: 0.9671197533607483
# Epoch 20, Bach 1 of 29
# mode: val, loss: 1.198401927947998
# Epoch 20, Bach 2 of 29
# mode: val, loss: 1.4021737575531006
# Epoch 20, Bach 3 of 29
# mode: val, loss: 1.4204027652740479
# Epoch 20, Bach 4 of 29
# mode: val, loss: 1.223922610282898
# Epoch 20, Bach 5 of 29
# mode: val, loss: 1.2083556652069092
# Epoch 20, Bach 6 of 29
# mode: val, loss: 1.1637814044952393
# Epoch 20, Bach 7 of 29
# mode: val, loss: 1.4660028219223022
# Epoch 20, Bach 8 of 29
# mode: val, loss: 28209.185546875
# Epoch 20, Bach 9 of 29
# mode: val, loss: 45367.40625
# Epoch 20, Bach 10 of 29
# mode: val, loss: 1374.529541015625
# Epoch 20, Bach 11 of 29
# mode: val, loss: 32708.896484375
# Epoch 20, Bach 12 of 29
# mode: val, loss: 272.4360656738281
# Epoch 20, Bach 13 of 29
# mode: val, loss: 6100.67578125
# Epoch 20, Bach 14 of 29
# mode: val, loss: 3528.3779296875
# Epoch 20, Bach 15 of 29
# mode: val, loss: 272.515625
# Epoch 20, Bach 16 of 29
# mode: val, loss: 5509.68212890625
# Epoch 20, Bach 17 of 29
# mode: val, loss: 1600.1025390625
# Epoch 20, Bach 18 of 29
# mode: val, loss: 585.5965576171875
# Epoch 20, Bach 19 of 29
# mode: val, loss: 379.4212341308594
# Epoch 20, Bach 20 of 29
# mode: val, loss: 1658.783203125
# Epoch 20, Bach 21 of 29
# mode: val, loss: 1968.5228271484375
# Epoch 20, Bach 22 of 29
# mode: val, loss: 317.8855285644531
# Epoch 20, Bach 23 of 29
# mode: val, loss: 689.310546875
# Epoch 20, Bach 24 of 29
# mode: val, loss: 1911.6605224609375
# Epoch 20, Bach 25 of 29
# mode: val, loss: 42.71303176879883
# Epoch 20, Bach 26 of 29
# mode: val, loss: 621.049560546875
# Epoch 20, Bach 27 of 29
# mode: val, loss: 1634.373046875
# Epoch 20, Bach 28 of 29
# mode: val, loss: 57.95441818237305
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan, 1.6751019954681396, nan, 0.9789684414863586, nan]
# Load: <torch.utils.data.dataloader.DataLoader object at 0x000001B3C5B77210>
# Epoch 20, Bach 29 of 4
# Epoch 20, Bach 30 of 4
# Epoch 20, Bach 31 of 4
# Epoch 20, Bach 32 of 4
# [750.171142578125, nan, 703.1624145507812, nan, 5.400332927703857, nan, 3.0144240856170654, nan, 1.8098955154418945, nan, 1.6529276371002197, nan, 1.65459406375885, nan, 3.263709306716919, nan, 2.0935652256011963, nan, 1.2870519161224365, nan, 0.854505181312561, nan, 0.9712470769882202, nan, 1.1281683444976807, nan, 1.2799394130706787, nan, 1.3658664226531982, nan, 1.3479626178741455, nan, 2.4581451416015625, nan, 1.6751019954681396, nan, 0.9789684414863586, nan, 57.95441818237305]

# %%
for i in range(len(v_all_losses)):
    # print(v_all_losses[i])
    # print(type(v_all_losses[i]))
    if not v_all_losses[i] > 0.5:
        v_all_losses[i] = 0

# %%
# Defining the Plot Style
plt.style.use('fivethirtyeight')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.loglog(all_losses)
# losses2 = np.array(losses2)
 
# Plotting the last 100 values
plt.plot(all_losses)
plt.title('Training Loss')
# losses
plt.show()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(v_all_losses)
plt.title('Validation Loss')
# plt.axis([0, 10, 0, 1000000000])
# Out:
# Text(0.5, 1.0, 'Validation Loss')
